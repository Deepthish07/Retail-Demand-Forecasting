# %%
import pandas as pd

# %%
two_year_sale=pd.read_excel("one year ebo sale data.xlsx")

# %%
two_year_sale.head()
# Out:
#     Inv Date            Time Zone Style Number  Category  \
# 0 2024-07-01  2024-07-01 12:36:46         1502  LEGGINGS
# 1 2024-07-01  2024-07-01 12:36:46         1502  LEGGINGS
# 2 2024-07-01  2024-07-01 12:36:46         1502  LEGGINGS
# 3 2024-07-01  2024-07-01 12:36:46         1502  LEGGINGS
# 4 2024-07-01  2024-07-01 12:36:46   PDA-WB-002      PANT
#
#                   Style Description                              Store  \
# 0  SOLID 4X4 FULL LEGGING - WOMEN'S  TBBA - TBF028 - FIVESTAR APPARELS
# 1  SOLID 4X4 FULL LEGGING - WOMEN'S  TBBA - TBF028 - FIVESTAR APPARELS
# 2  SOLID 4X4 FULL LEGGING - WOMEN'S  TBBA - TBF028 - FIVESTAR APPARELS
# 3  SOLID 4X4 FULL LEGGING - WOMEN'S  TBBA - TBF028 - FIVESTAR APPARELS
# 4          WOMEN'S KNITTED AOP PANT  TBBA - TBF028 - FIVESTAR APPARELS
#
#           Color Size  Qty  Rate  Net Amount   State Channel Unnamed: 13
# 0  NAVY CLASSIC  2XL    1   549      2795.0  KERALA     EBO         NaN
# ...
